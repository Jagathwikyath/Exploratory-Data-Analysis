# %%
#Exploratary data analysis 
#Major project 
#getting the data set 
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
from sklearn.linear_model import LinearRegression
data = pd.read_csv('/content/honeyproduction.csv')
data
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %%
sameyear = data.iloc[:43]
sameyear
# Out:
#    state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0     AL   16000.0           71   1136000.0    159000.0        0.72
# 1     AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2     AR   53000.0           65   3445000.0   1688000.0        0.59
# 3     CA  450000.0           83  37350000.0  12326000.0        0.62
# 4     CO   27000.0           72   1944000.0   1594000.0        0.70
# 5     FL  230000.0           98  22540000.0   4508000.0        0.64
# 6     GA   75000.0           56   4200000.0    307000.0        0.69
# 7     HI    8000.0          118    944000.0     66000.0        0.77
# 8     ID  120000.0           50   6000000.0   2220000.0        0.65
# 9     IL    9000.0           71    639000.0    204000.0        1.19
# 10    IN    9000.0           92    828000.0    489000.0        0.85
# 11    IA   50000.0           78   3900000.0   2301000.0        0.70
# 12    KS   16000.0           46    736000.0    390000.0        0.87
# ...

# %%
pstate=sameyear['state'].unique()
pstate
# Out:
# array(['AL', 'AZ', 'AR', 'CA', 'CO', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN',
#        'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MI', 'MN', 'MS', 'MO', 'MT',
#        'NE', 'NV', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA',
#        'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY'],
#       dtype=object)

# %%
production=sameyear['prodvalue'].values
production
# Out:
# array([  818000.,  2112000.,  2033000., 23157000.,  1361000., 14426000.,
#         2898000.,   727000.,  3900000.,   760000.,   704000.,  2730000.,
#          640000.,   210000.,  2685000.,   179000.,   339000.,  4488000.,
#         7189000.,   898000.,  1154000.,  8979000.,  3853000.,   759000.,
#          410000.,   585000.,  3640000.,   651000., 18547000.,  1165000.,
#          253000.,  2025000.,  1373000., 13680000.,   591000.,  4344000.,
#         1131000.,   326000.,   394000.,  1893000.,   376000.,  5831000.,
#         1877000.])

# %%
#Data visualization 
plt.bar(pstate, production)
plt.xlabel("States")
plt.ylabel("Production value")
plt.title("IN A SAME YEAR STATES VS PRODUCITON VALUE")
plt.show()

# %%
#Regressor to be selected
#Linear regressor 

regression = LinearRegression()
#input for the model be in x
#output of the model be in y
x = sameyear.iloc[:,1:2]
x
# Out:
#       numcol
# 0    16000.0
# 1    55000.0
# 2    53000.0
# 3   450000.0
# 4    27000.0
# 5   230000.0
# 6    75000.0
# 7     8000.0
# 8   120000.0
# 9     9000.0
# 10    9000.0
# 11   50000.0
# 12   16000.0
# 13    3000.0
# 14   41000.0
# 15   10000.0
# 16    7000.0
# 17   80000.0
# 18  140000.0
# 19   18000.0
# 20   23000.0
# 21  115000.0
# 22   64000.0
# 23   10000.0
# 24   11000.0
# 25   14000.0
# 26   65000.0
# 27    8000.0
# 28  230000.0
# 29   18000.0
# 30    4000.0
# 31   50000.0
# 32   26000.0
# 33  225000.0
# 34    7000.0
# 35   91000.0
# 36   30000.0
# 37    6000.0
# 38    8000.0
# 39   58000.0
# 40    6000.0
# 41   89000.0
# 42   46000.0

# %%
highestvalue = production.max()
lowestvalue = production.min()
print(highestvalue)
print(lowestvalue)
# Out:
# 23157000.0
# 179000.0

# %%
#y be the output of the model
y = sameyear.iloc[:,6]
y
# Out:
# 0       818000.0
# 1      2112000.0
# 2      2033000.0
# 3     23157000.0
# 4      1361000.0
# 5     14426000.0
# 6      2898000.0
# 7       727000.0
# 8      3900000.0
# 9       760000.0
# 10      704000.0
# 11     2730000.0
# 12      640000.0
# 13      210000.0
# 14     2685000.0
# 15      179000.0
# 16      339000.0
# 17     4488000.0
# 18     7189000.0
# 19      898000.0
# 20     1154000.0
# 21     8979000.0
# 22     3853000.0
# 23      759000.0
# 24      410000.0
# 25      585000.0
# 26     3640000.0
# 27      651000.0
# 28    18547000.0
# 29     1165000.0
# 30      253000.0
# 31     2025000.0
# 32     1373000.0
# 33    13680000.0
# 34      591000.0
# 35     4344000.0
# 36     1131000.0
# 37      326000.0
# 38      394000.0
# 39     1893000.0
# 40      376000.0
# 41     5831000.0
# 42     1877000.0
# Name: prodvalue, dtype: float64

# %%
#training the model
regressor = LinearRegression()
fit = regressor.fit(x,y)
fit
# Out:
# LinearRegression()

# %%
#Prediction of the value
pred = regressor.predict(x)
pred
# Out:
# array([  799861.43074136,  3053447.24587159,  2937878.74253158,
#        25878226.65552392,  1435488.19911143, 13165691.28812262,
#         4209132.27927171,   337587.41738132,  6809423.60442198,
#          395371.66905132,   395371.66905132,  2764525.98752156,
#          799861.43074136,    48666.15903129,  2244467.72249151,
#          453155.92072133,   279803.16571131,  4498053.53762174,
#         7965108.63782209,   915429.93408137,  1204351.1924314 ,
#         6520502.34607195,  3573505.51090165,   453155.92072133,
#          510940.17239133,   684292.92740135,  3631289.76257165,
#          337587.41738132, 13165691.28812262,   915429.93408137,
#          106450.41070129,  2764525.98752156,  1377703.94744142,
#        12876770.02977259,   279803.16571131,  5133680.30599181,
#         1608840.95412145,   222018.9140413 ,   337587.41738132,
#         3226800.00088161,   222018.9140413 ,  5018111.80265179,
#         2533388.98084154])

# %%
#Normalizing
normal = production/1000
normal
# Out:
# array([  818.,  2112.,  2033., 23157.,  1361., 14426.,  2898.,   727.,
#         3900.,   760.,   704.,  2730.,   640.,   210.,  2685.,   179.,
#          339.,  4488.,  7189.,   898.,  1154.,  8979.,  3853.,   759.,
#          410.,   585.,  3640.,   651., 18547.,  1165.,   253.,  2025.,
#         1373., 13680.,   591.,  4344.,  1131.,   326.,   394.,  1893.,
#          376.,  5831.,  1877.])

# %%
#Now to cross verify the prediction we should use this method 
#y = mx +c
cross = regressor.predict([[3000]])
cross
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([48666.15903129])

# %%
#actual values y 
plt.scatter(x,y)
plt.xlabel('Number of columns')
plt.ylabel("Production")
plt.title("Production value")
# Out:
# Text(0.5, 1.0, 'Production value')

# %%
#Cross checking 
#Linear so y = mx+c
m = regressor.coef_
c = regressor.intercept_
m*3000 + c
# Out:
# array([48666.15903129])

# %%
#To check the accuracy of the model 
plt.scatter(x,y)
plt.plot(x,pred,color='yellow')
plt.xlabel('Number of columns')
plt.ylabel("Production")
plt.title("Production value")
# Out:
# Text(0.5, 1.0, 'Production value')
